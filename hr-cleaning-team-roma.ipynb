# %%
# Importing necessary libraries
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)

# Listing files in the Kaggle input directory
import os
for dirname, _, filenames in os.walk('/kaggle/input'):  # First 'for' loop
    for filename in filenames:  # Second 'for' loop (indented properly)
        print(os.path.join(dirname, filename))  # Indented under the second 'for'
# Out:
# /kaggle/input/hr-data/WA_Fn-UseC_-HR-Employee-Attrition.csv
# /kaggle/input/hrlflfllflf/notebookacbfed96ca.ipynb

# %%
df=pd.read_csv(r"/kaggle/input/hr-data/WA_Fn-UseC_-HR-Employee-Attrition.csv", low_memory=False)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
nRow, nCol = df.shape
print(f"There are {nRow} rows and {nCol} columns in this dataset.")
# Out:
# There are 1470 rows and 35 columns in this dataset.

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
Education_mapping={
    1:'Below College',
    2:'College',
    3: 'Bachelor',
    4: 'Master',
    5: 'Doctor'
}

# %%
 df['Education'].replace(Education_mapping,inplace=True)
# Out:
# /tmp/ipykernel_30/2591003207.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Education'].replace(Education_mapping,inplace=True)

# %%
EnvironmentSatisfaction_mapping={
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High',
}

# %%
 df['EnvironmentSatisfaction'].replace(EnvironmentSatisfaction_mapping,inplace=True)
# Out:
# /tmp/ipykernel_30/2049665732.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['EnvironmentSatisfaction'].replace(EnvironmentSatisfaction_mapping,inplace=True)

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 0                 1        College  Life Sciences              1
# 1                 8  Below College  Life Sciences              1
# 2                 2        College          Other              1
# 3                 3         Master  Life Sciences              1
# 4                 2  Below College        Medical              1
#
#    EmployeeNumber  ... RelationshipSatisfaction StandardHours  \
# 0               1  ...                        1            80
# ...

# %%
JobInvolvement_mapping={
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High',
}

# %%
 df['JobInvolvement'].replace(JobInvolvement_mapping,inplace=True)
# Out:
# /tmp/ipykernel_30/3490492495.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['JobInvolvement'].replace(JobInvolvement_mapping,inplace=True)

# %%
JobSatisfaction_mapping={
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High',
}

# %%
 df['JobSatisfaction'].replace(JobSatisfaction_mapping,inplace=True)
# Out:
# /tmp/ipykernel_30/4200840482.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['JobSatisfaction'].replace(JobSatisfaction_mapping,inplace=True)

# %%
PerformanceRating_mapping={
    1:'Low',
    2 :'Good',
    3 :'Excellent',
    4 :'Outstanding'
}

# %%
df['PerformanceRating'].replace(PerformanceRating_mapping,inplace=True)
# Out:
# /tmp/ipykernel_30/834625558.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PerformanceRating'].replace(PerformanceRating_mapping,inplace=True)

# %%
RelationshipSatisfaction_mapping={
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High',
}

# %%
df['RelationshipSatisfaction'].replace(RelationshipSatisfaction_mapping,inplace=True)
# Out:
# /tmp/ipykernel_30/3395077840.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['RelationshipSatisfaction'].replace(RelationshipSatisfaction_mapping,inplace=True)

# %%
WorkLifeBalance_mapping={
    1: 'Bad',
    2: 'Good',
    3: 'Better',
    4: 'Best'
}

# %%
df['WorkLifeBalance'].replace(WorkLifeBalance_mapping,inplace=True)
# Out:
# /tmp/ipykernel_30/4194066549.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['WorkLifeBalance'].replace(WorkLifeBalance_mapping,inplace=True)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 0                 1        College  Life Sciences              1
# 1                 8  Below College  Life Sciences              1
# 2                 2        College          Other              1
# 3                 3         Master  Life Sciences              1
# 4                 2  Below College        Medical              1
#
#    EmployeeNumber  ... RelationshipSatisfaction StandardHours  \
# 0               1  ...                      Low            80
# ...

# %%
categorical_columns = df.select_dtypes(exclude=np.number).columns
numerical_columns = df.select_dtypes(include=np.number).columns

# %%
categorical_columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'Education',
#        'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement',
#        'JobRole', 'JobSatisfaction', 'MaritalStatus', 'Over18', 'OverTime',
#        'PerformanceRating', 'RelationshipSatisfaction', 'WorkLifeBalance'],
#       dtype='object')

# %%
numerical_columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'EmployeeCount',
#        'EmployeeNumber', 'HourlyRate', 'JobLevel', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
for i in categorical_columns:
    print('\n')
    print(df[i].value_counts())
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
#
#
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
#
#
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
#
#
# Education
# Bachelor         572
# Master           398
# College          282
# Below College    170
# Doctor            48
# Name: count, dtype: int64
#
#
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
#
#
# EnvironmentSatisfaction
# High         453
# Very High    446
# Medium       287
# Low          284
# Name: count, dtype: int64
#
#
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64
#
#
# JobInvolvement
# High         868
# Medium       375
# Very High    144
# ...

# %%
for i in numerical_columns:
    print("\n ")
    print(df[i].value_counts())
# Out:
#
# Age
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: count, dtype: int64
#
#
# DailyRate
# 691     6
# 408     5
# 530     5
# 1329    5
# 1082    5
#        ..
# 650     1
# 279     1
# 316     1
# 314     1
# 628     1
# Name: count, Length: 886, dtype: int64
#
#
# DistanceFromHome
# 2     211
# 1     208
# 10     86
# 9      85
# 3      84
# 7      84
# 8      80
# 5      65
# 4      64
# 6      59
# 16     32
# 11     29
# 24     28
# 23     27
# 29     27
# 15     26
# 18     26
# 26     25
# 25     25
# 20     25
# 28     23
# 19     22
# 14     21
# ...

# %%
df['JobInvolvement'].unique()
# Out:
# array(['High', 'Medium', 'Very High', 'Low'], dtype=object)

# %%
df['JobLevel'].unique()
# Out:
# array([2, 1, 3, 4, 5])

# %%
bins = [18, 30, 45, 60] 
labels = ['18-30', '31-45', '46-60'] 

df['AgeRange'] = pd.cut(df['Age'], bins=bins, labels=labels, right=True)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'AgeRange'],
#       dtype='object')

# %%
df.tail(30)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1440   36        No  Travel_Frequently        688  Research & Development
# 1441   56        No         Non-Travel        667  Research & Development
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1443   42        No      Travel_Rarely        300  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1445   41        No      Travel_Rarely        582  Research & Development
# 1446   34        No      Travel_Rarely        704                   Sales
# 1447   36        No         Non-Travel        301                   Sales
# 1448   41        No      Travel_Rarely        930                   Sales
# 1449   32        No      Travel_Rarely        529  Research & Development
# 1450   35        No      Travel_Rarely       1146         Human Resources
# 1451   38        No      Travel_Rarely        345                   Sales
# ...

# %%
import seaborn as sns
p = ["#A04747" , "#D8A25E","#EEDF7A"]
c = sns.countplot(data=df , x='AgeRange', palette=p,hue='Gender')
for patch in c.patches:
    patch.set_edgecolor('black') 
    patch.set_linewidth(2)

plt.title("Distribution of Age Ranges by Gender")
plt.xlabel("Age Range", fontsize=14)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
import matplotlib.pyplot as plt 

# Define colors
c = ["#243642", "#629584"]

# Count values in the 'Attrition' column
Attrition_counts = df['Attrition'].value_counts()

# Create the pie chart
plt.pie(
    Attrition_counts,
    labels=Attrition_counts.index,  # Use index for proper labels
    shadow=False,
    labeldistance=1.2,
    explode=(0.1, 0),  # Use tuple for explode
    colors=c,
    autopct='%.1f%%',
    wedgeprops=dict(edgecolor='black'),
    textprops={'fontsize': 15,'color': '#CB6040'}  # Font size for text
)

# Set the title
plt.title('Distribution of Attrition', fontsize=18)  # Set title font size
plt.show()

# %%
p = ["#243642" , "#629584"]
     
c = sns.countplot(data=df , x='EnvironmentSatisfaction', palette=p,hue='Gender')
for patch in c.patches:
    patch.set_edgecolor('black') 
    patch.set_linewidth(2)

plt.title("Environment Satisfaction by Gender")
plt.xlabel("EnvironmentSatisfaction", fontsize=14)
plt.show()

# %%
# df.to_csv("/kaggle/input/hr-data/WA_Fn-UseC_-HR-Employee-Attrition.csv", index=False)

# %%
df['Age'].describe().T
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %%
# df.drop(['Ranged Age Names'], axis=1)

# %%
job_level_mapping = {
    1: 'Junior Level',
    2: 'Medior',
    3: 'Senior',
    4: 'Team Leader',
    5: 'Supervisor'
}

df['ExperienceLevel'] = df['JobLevel'].map(job_level_mapping)

# %%
plt.figure(figsize=(10,6))
color = ["#243642" , "#629584"]

sns.histplot(x="ExperienceLevel",hue="Attrition",data=df,kde=False,palette=color)
plt.title("Experience Level Distribution by Attrition Status")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 0                 1        College  Life Sciences              1
# ...

# %%
df['HourlyRate'].describe()
# Out:
# count    1470.000000
# mean       65.891156
# std        20.329428
# min        30.000000
# 25%        48.000000
# 50%        66.000000
# 75%        83.750000
# max       100.000000
# Name: HourlyRate, dtype: float64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'AgeRange', 'ExperienceLevel'],
#       dtype='object')

# %%
df['Education'].value_counts()
# Out:
# Education
# Bachelor         572
# Master           398
# College          282
# Below College    170
# Doctor            48
# Name: count, dtype: int64

# %%
df[['Education', 'Attrition', 'HourlyRate']]
# Out:
#           Education Attrition  HourlyRate
# 0           College       Yes          94
# 1     Below College        No          61
# 2           College       Yes          92
# 3            Master        No          56
# 4     Below College        No          40
# ...             ...       ...         ...
# 1465        College        No          41
# 1466  Below College        No          42
# 1467       Bachelor        No          87
# 1468       Bachelor        No          63
# 1469       Bachelor        No          82
#
# [1470 rows x 3 columns]

# %%
c = ["#243642" , "#629584"]
c = sns.countplot(data=df,x='Education',hue='Attrition',palette=c)
for patch in c.patches:
    patch.set_edgecolor('black') 
    patch.set_linewidth(1.5)

plt.title("Attrition by Education Level")
plt.show()

# %%
# fcolors = [ "#C4DAD2" ,"#16423C"]
# colors = [ "#003C43" ,"#E5D9F2"]
# sns.histplot(data=df, x='Education', hue='Attrition',stat='percent',palette=colors)

# %%
df['MonthlyIncome'].describe().T
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
sns.lineplot(data=df,x='Education',y='MonthlyIncome',color='#00CCDD')
plt.title("Education Level vs. Monthly Income")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Education Level vs. Monthly Income')

# %%
palette =["#D1BB9E","#A79277", "#795757" ,"#664343" ,"#3B3030"]
barplot = sns.barplot(data=df,y='Education',x='MonthlyIncome', errorbar=None,palette=palette)
for patch in barplot.patches:
    patch.set_edgecolor('black') 
    patch.set_linewidth(2)

# %%
df.MonthlyIncome
# Out:
# 0       5993
# 1       5130
# 2       2090
# 3       2909
# 4       3468
#         ...
# 1465    2571
# 1466    9991
# 1467    6142
# 1468    5390
# 1469    4404
# Name: MonthlyIncome, Length: 1470, dtype: int64

# %%
# palette =["#D1BB9E","#A79277", "#795757" ,"#664343" ,"#3B3030"]

# sns.countplot(data=df,x='Education',palette=palette)

# %%
df[df['YearsAtCompany']==40]
# Out:
#      Age Attrition BusinessTravel  DailyRate              Department  \
# 126   58       Yes  Travel_Rarely        147  Research & Development
#
#      DistanceFromHome Education EducationField  EmployeeCount  EmployeeNumber  \
# 126                23    Master        Medical              1             165
#
#      ... StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 126  ...                1                40                      3
#
#     WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 126            Good              40                 10
#
#     YearsSinceLastPromotion YearsWithCurrManager  AgeRange  ExperienceLevel
# 126                      15                    6     46-60           Senior
#
# [1 rows x 37 columns]

# %%
attrition_rate = df['Attrition'].value_counts(normalize=True) * 100
print("Attrition Rate:\n", attrition_rate)
# Out:
# Attrition Rate:
#  Attrition
# No     83.877551
# Yes    16.122449
# Name: proportion, dtype: float64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'AgeRange', 'ExperienceLevel'],
#       dtype='object')

# %%
c = ["#243642" , "#387478","#E2F1E7"]


x = sns.countplot(data = df,x=df["Department"] , palette=c)
for patch in x.patches:
    patch.set_edgecolor('black') 
    patch.set_linewidth(2)
plt.title("Number of Each Department in The Company")
plt.ylabel("Counts" , fontsize=14)
plt.xlabel("Department",fontsize=14)
plt.show()

# %%
c = ["#243642" , "#387478","#E2F1E7"]

barplot = sns.barplot(data=df, x="Department", y="MonthlyIncome", estimator=sum , errorbar=None,palette=c )
for patch in barplot.patches:
    patch.set_edgecolor('black') 
    patch.set_linewidth(2)       
plt.title("Total Monthly Income by Department")
plt.ylabel("MonthlyIncome" , fontsize=14)
plt.xlabel("Department",fontsize=14)
plt.show()

# %%
print("zalata")
# Out:
# zalata

# %%
# sns.scatterplot(x='PerformanceRating', y='PercentSalaryHike', data=df)
# plt.title('Performance Rating vs. Percent Salary Hike')
# plt.show()

# %%
# df['WorkLifeBalance'] = df['WorkLifeBalance'].astype(int)
# df['JobSatisfaction'] = df['JobSatisfaction'].astype(int)

# # Now plot the bar chart
# sns.barplot(x='WorkLifeBalance', y='JobSatisfaction', data=df)
# plt.title('Job Satisfaction vs. Work-Life Balance')
# plt.show()

# %%
c = ["#243642" , "#629584"]

overtime_distance = df.groupby('OverTime')['DistanceFromHome'].mean()

plt.pie(overtime_distance, labels=overtime_distance.index, autopct='%1.1f%%',shadow=True,colors=c,textprops={'color': 'white'}, 
        wedgeprops={'edgecolor': 'black', 'linewidth': 2})
plt.title('Average Distance from Home for Overtime Status')

plt.show()

# %%
c = ["#243642" , "#629584"]


import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))  # Set the figure size

# Create the barplot
barplot = sns.barplot(data=df, x='JobSatisfaction', y='DistanceFromHome', hue='Attrition', estimator='mean', errorbar=None,palette=c)
for patch in barplot.patches:
    patch.set_edgecolor('white') 
    patch.set_linewidth(4)
# Set custom font sizes for axes labels and ticks
plt.title('Job Satisfaction vs. Avg Distance From Home by Attrition', fontsize=20)
plt.xlabel('Job Satisfaction', fontsize=16)
plt.ylabel('Distance From Home (Miles)', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Display the plot
plt.show()

# %%
# df['PerformanceRating'] = df['PerformanceRating'].astype(int)

# sns.barplot(data=df, x='BusinessTravel', y='PerformanceRating')
# plt.title('Performance Rating by Business Travel')
# plt.show()
